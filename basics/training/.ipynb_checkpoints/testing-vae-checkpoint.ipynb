# %%
# %matplotlib inline
import torch
from basics.nets.mlp_encoder import Encoder
from basics.nets.mlp_decoder import Decoder
from torchvision import datasets, transforms

CUDA = torch.cuda.is_available()
if CUDA:
    device = torch.device('cuda:1')
print('torch:', torch.__version__, 'CUDA:', CUDA)
pixel_dim = 784
latent_dim = 10
sample_size = 1
hidden_dim = 128
batch_size = 100
reparameterized = True

data_dir = '/home/hao/Research/sebm_data/'
transform = transforms.Compose([transforms.ToTensor(),
                                    transforms.Normalize((0.5,),(0.5,))]) 
data = torch.utils.data.DataLoader(
                    datasets.MNIST(data_dir, train=False, download=True,
                                   transform=transform),
                    batch_size=batch_size, shuffle=True) 

print('Initialize encoder and decoder and optimizer...')
enc = Encoder(latent_dim, hidden_dim, pixel_dim, reparameterized=reparameterized)
dec = Decoder(latent_dim, hidden_dim, pixel_dim, CUDA, device)
if CUDA:
    with torch.cuda.device(device):
        enc.cuda()  
        dec.cuda()
print('Loading trained models...')
load_version = 'vae-mnist-zd=%s' % (latent_dim)
enc.load_state_dict(torch.load('../weights/rws-mlp-enc-%s' % load_version))
dec.load_state_dict(torch.load('../weights/rws-mlp-dec-%s' % load_version))
# Out:
# torch: 1.6.0 CUDA: True
# Initialize encoder and decoder and optimizer...
# Loading trained models...
# <All keys matched successfully>

# %%
from basics.eval import plot_samples, compress_tsne, plot_tsne

# for (images, _) in data:
#     break
# images = images.squeeze().view(batch_size, 784).repeat(sample_size, 1, 1).cuda().to(device)
# latents, _ = enc.forward(images)
# _, recons, _ = dec.forward(latents, images)
# plot_samples(recons.view(sample_size, batch_size, 28, 28))

# %%
zs2, ys = compress_tsne(data, enc, dec, device, sample_size)
plot_tsne(num_classes, zs2, ys)
# Out:
# run test set..
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-e35fe4a8acff> in <module>
# ----> 1 zs2, ys = compress_tsne(data, enc, dec, device)
#       2 plot_tsne(num_classes, zs2, ys)
#
# ~/Research/sebm/basics/eval.py in compress_tsne(test_data, enc, dec, device)
#      28     for (images, labels) in test_data:
#      29         images = images.cuda().to(device)
# ---> 30         latents, _ = enc(images)
#      31         latents = latents.squeeze().cpu().detach().numpy()
#      32         zs.append(latents)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/Research/sebm/basics/nets/mlp_encoder.py in forward(self, images)
#      26
#      27     def forward(self, images):
# ---> 28         h = self.hidden(images)
#      29         q_mu = self.q_mu(h)
#      30         q_sigma = self.q_log_sigma(h).exp()
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      89
#      90     def forward(self, input: Tensor) -> Tensor:
# ---> 91         return F.linear(input, self.weight, self.bias)
#      92
#      93     def extra_repr(self) -> str:
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1674         ret = torch.addmm(bias, input, weight.t())
#    1675     else:
# -> 1676         output = input.matmul(weight.t())
#    1677         if bias is not None:
#    1678             output += bias
#
# RuntimeError: mat1 dim 1 must match mat2 dim 0

# %%
from ffebm.data import load_mnist
_, test_data = load_mnist(data_dir, test_batch_size)
for (images, _) in test_data:
    break

# %%
import numpy as np
a = np.load('/home/hao/Research/train-images-idx3-ubyte', allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     453             try:
# --> 454                 return pickle.load(fid, **pickle_kwargs)
#     455             except Exception:
#
# UnpicklingError: invalid load key, '\x00'.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-6c6532c2c083> in <module>
#       1 import numpy as np
# ----> 2 a = np.load('/home/hao/Research/train-images-idx3-ubyte', allow_pickle=True)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     455             except Exception:
#     456                 raise IOError(
# --> 457                     "Failed to interpret file %s as a pickle" % repr(file))
#     458     finally:
#     459         if own_fid:
#
# OSError: Failed to interpret file '/home/hao/Research/train-images-idx3-ubyte' as a pickle

# %%
# from ffebm.patches import vis_patches_one_image
# mnist_data_dir = '../../../sebm_data/'
# vis_patches_one_image(patch_size, mnist_data_dir)
